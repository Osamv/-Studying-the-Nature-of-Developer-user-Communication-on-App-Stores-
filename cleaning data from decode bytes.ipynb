# %%
# reading data
import pandas as pd
data_noon = pd.read_excel('dataset/aramex.xlsx')

# %%
data = data_noon.copy()
data.head()
# Out:
#         source                             review_id            user_name  \
# 0  Google Play  d855686a-7ebe-4cef-911f-3d124bc2d61a  ‫عمرو محمد (داود)‬‎
# 1  Google Play  0491e3b8-c262-4ef3-ab74-4a962a7a28ee         Moath Tobasi
# 2  Google Play  0b537bf6-2dc3-4d4b-b239-6e6b916eaadc     Mohamed Mohamedy
# 3  Google Play  5e50884e-e69a-4d05-8ae3-0b0aea7f278c          temoo tamam
# 4  Google Play  c29dbb95-8dfa-4918-94ca-5e124d405930           tufool mab
#
#    review_title                                 review_description  rating  \
# 0           NaN                                          very good       5
# 1           NaN  ارمكس برنامج ممتاز لا يوجد اي تعليق المواعيد ف...       5
# 2           NaN                                        فوق الممتاز       5
# 3           NaN  خدمة سيئة جدا وعدم الالتزام بمواعيد التسليم وخ...       1
# 4           NaN                          شكرا على حسن تعاونكم معنا       5
#
#    thumbs_up         review_date  \
# ...

# %%
# drop unnecessary columns 
data.drop(['thumbs_up','laguage_code','country_code'], axis=1, inplace=True)
#data.drop(['thumbs_up'], axis=1, inplace=True)
data.head()
# Out:
#         source                             review_id            user_name  \
# 0  Google Play  d855686a-7ebe-4cef-911f-3d124bc2d61a  ‫عمرو محمد (داود)‬‎
# 1  Google Play  0491e3b8-c262-4ef3-ab74-4a962a7a28ee         Moath Tobasi
# 2  Google Play  0b537bf6-2dc3-4d4b-b239-6e6b916eaadc     Mohamed Mohamedy
# 3  Google Play  5e50884e-e69a-4d05-8ae3-0b0aea7f278c          temoo tamam
# 4  Google Play  c29dbb95-8dfa-4918-94ca-5e124d405930           tufool mab
#
#    review_title                                 review_description  rating  \
# 0           NaN                                          very good       5
# 1           NaN  ارمكس برنامج ممتاز لا يوجد اي تعليق المواعيد ف...       5
# 2           NaN                                        فوق الممتاز       5
# 3           NaN  خدمة سيئة جدا وعدم الالتزام بمواعيد التسليم وخ...       1
# 4           NaN                          شكرا على حسن تعاونكم معنا       5
#
# ...

# %%
# check missing values
#data.isna().sum()

# %%
data.isna().sum()[data.isna().sum()>0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# drop review_title columns it has all value null, it's unnecessary columns 
data.drop(['review_title'], axis=1 , inplace=True)
data.head()
# Out:
#         source                             review_id            user_name  \
# 0  Google Play  d855686a-7ebe-4cef-911f-3d124bc2d61a  ‫عمرو محمد (داود)‬‎
# 1  Google Play  0491e3b8-c262-4ef3-ab74-4a962a7a28ee         Moath Tobasi
# 2  Google Play  0b537bf6-2dc3-4d4b-b239-6e6b916eaadc     Mohamed Mohamedy
# 3  Google Play  5e50884e-e69a-4d05-8ae3-0b0aea7f278c          temoo tamam
# 4  Google Play  c29dbb95-8dfa-4918-94ca-5e124d405930           tufool mab
#
#                                   review_description  rating  \
# 0                                          very good       5
# 1  ارمكس برنامج ممتاز لا يوجد اي تعليق المواعيد ف...       5
# 2                                        فوق الممتاز       5
# 3  خدمة سيئة جدا وعدم الالتزام بمواعيد التسليم وخ...       1
# 4                          شكرا على حسن تعاونكم معنا       5
#
#           review_date                                 developer_response  \
# 0 2023-01-04 15:47:27  We sincerely thank you for taking the time to ...
# ...

# %%
data.isna().sum()[data.isna().sum()>0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# check data shape befor drop row null
data.shape
# Out:
# (5710, 8)

# %%
#save data to csv file after cleaning data
data.to_csv("aramex.csv", encoding='utf-8-sig', index=False , header=True)
